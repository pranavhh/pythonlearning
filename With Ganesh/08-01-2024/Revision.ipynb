# %%
"""
This is a function named  "hello_world" which prints "Happy New Year"
This was given as a excercise by Ganesh Jawhar. The Question was:
"Write a function "hello_world" that prints "Happy New Year!"
"""
def hello_world():
  print("Happy New Year!")

hello_world()"""
This is a function named "add_numbers" which has 2 inputs and the output will be the sum of the imputs.
 This was an excercise by GANESH JAWAHAR. The question was:
  "Write a function "add_numbers" that takes two numbers as inputs and prints the sum of those two numbers.

"""
def add_numbers(a,b):
    print(a+b)

add_numbers (5,10)
add_numbers (-20,-10)

"""
This is a extension of the previous function where I print the result outside the "add_number" function with the help of the return keyword.

The meaning of the new keyword in python named Return

Return - Return is a python key word that returns the result of  the current function usually (Explanation
 by GANESH JAWAHAR)
 (or)

 The Python return statement is a special statement that you can use inside a function
  or method to send the function's result back to the caller. A return statement consists of the
   return keyword followed by an optional return value. The return value of a Python function can
   be any Python object. (Explanation by Google)

"""
def add_numbers(a,b):
    return(a+b)

print(add_numbers (5,10))
print (add_numbers (-20,-10))
# Out:
# 15
# -30
