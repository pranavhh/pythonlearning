# %% [markdown]
# Let us make a  simulation of the login.

# %%
email_password_data = {
    "pranav@apple.com": "Harish@1234",
    "harish@google.com": "Hema@5678",
    "hema@chatgpt.com": "Thendral@9012",
    "thendral@perplexity.com": "Thaariga@3456",
    "thaariga@noggler.com": "Sindhu@7890",
    "sindhu@looveapple.com": "Jai@2345",
    "jai@ai.com": "Jawahar@6789",
    "jawahar@artificialintelligence.com": "Meena@1234",
    "meena@apple.com": "Santhi@5678",
    "santhi@google.com": "Muthukrishnan@9012",
    "muthukrishnan@chatgpt.com": "Pranav@3456",
    "akhil@perplexity.com": "Vikram@7890",
    "vikram@noggler.com": "Aditya@2345",
    "aditya@looveapple.com": "Karthik@6789",
    "karthik@ai.com": "Anusha@1234",
    "anusha@artificialintelligence.com": "Rajesh@5678",
    "rajesh@apple.com": "Sneha@9012",
    "sneha@google.com": "Vani@3456",
    "vani@chatgpt.com": "Kiran@7890",
    "kiran@perplexity.com": "Ravi@2345",
    "ravi@noggler.com": "Arjun@6789",
    "arjun@looveapple.com": "Divya@1234",
    "divya@ai.com": "Nisha@5678",
    "nisha@artificialintelligence.com": "Praveen@9012",
    "praveen@apple.com": "Ramesh@3456",
    "ramesh@google.com": "Suresh@7890",
    "suresh@chatgpt.com": "Geetha@2345",
    "geetha@perplexity.com": "Manoj@6789",
    "manoj@noggler.com": "Vidhya@1234",
    "vidhya@looveapple.com": "Mohan@5678",
    "mohan@ai.com": "Deepa@9012"
}

input_email = input("Enter your email: ")
input_password = input("Enter your password: ")

if input_email in email_password_data:
    if email_password_data[input_email] == input_password:
        print("Access granted! You are successfully logged in.")
    else:
        print("Access denied! Incorrect password.")
else:
    print("Access denied! Email not found.")
# Out:
# Enter your email: jai@ai.com
# Enter your password: Jawahar@6789
# Access granted! You are successfully logged in.

# %%
#This is a machine that will say True if a and b are equal and false if not
a=20
b=18

print (a!=b)
# Out:
# True

# %%
#Now, let us make a app. that will figure out if you are elgibble too vote or not
age = int(input("Enter your age:"))

if (age) == 18:
  print ("As you are 18 years old, you are eligible to vote")
elif (age) > 18:
 print ("As you are more than 18 years old, you are eligible to vote")
else:
  print ("You are not 18 years old, hence, you are not eligible to vote")
# Out:
# Enter your age:0
# You are not 18 years old, hence, you are not eligible to vote

# %%
age = int(input("Enter your age :  "))#This is another way which we can make the previous app
if age >= 18:
  print ("As you are 18+ years old, you are eligible to vote.")
else:
  print ("As you are not 18 years old yet, you are not eligible to vote")
# Out:
# Enter your age :  0
# As you are not 18 years old yet, you are not eligible to vote

# %%
#Now let us see how to make a app that will check which number is greater if you enter any two numbers
num1 = int(input("Choose a number:"))
num2 = int(input('Choose another number:'))

if num1 > num2:
  print (f"{num1} is greater than {num2}")
else:
  print(f"{num2} is greater than {num2}")
# Out:
# Choose a number:0
# Choose another number:0
# 0 is greater than 0

# %%
#Lastly, let's make a app thatwill check if you are eligible to to ride a camel or not
name= str(input("Enter your name:  "))
age= int(input("Enter your age: "))
height_in_cm=float(input("Enter your age in cm: "))

if age >= 18 and height_in_cm >=160:
  print ("You're eligible for the ride, " , name)
else:
  print ("You're not eligible for the ride, " , name)
# Out:
# Enter your name:  0
# Enter your age: 0
# Enter your age in cm: 0
# You're not eligible for the ride,  0
