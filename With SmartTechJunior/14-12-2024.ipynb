# %%
n=int(input("Enter the length of the list:"))

print ("LENGTH OF THE LIST:",n)

l=[]#empty list
for i in range (0,n):
  j=input("Enter the value")
  l.append(j)

print (l)
# Out:
# Enter the length of the list:01
# LENGTH OF THE LIST: 1
# Enter the valueHi
# ['Hi']

# %% [markdown]
# TUPLE

# %%
#Dictionnary
Dictionary=  {
    "Name" : "Harish Jawahar",
    "Father": "Jawahar Sankarlingam",
    "Mother": "Meenakumari Arultharumperumal",
    "Spouse": "Hemahlathaa Muthukrishnan",
    "Country in which having visa" : ["Singapoore" , "India" , "United States of America" , "Canada" , "Malaysia" , "Indonesia"],
    "Nationality"  : "India"
}

print (Dictionary["Name"])
print (Dictionary["Father"])
print (Dictionary["Mother"])
print (Dictionary["Spouse"])
print (Dictionary["Country in which having visa"])
print (Dictionary['Nationality'])

print (Dictionary)

Dictionary["Name"]="Harish J"#Modifiication
print (Dictionary)
Dictionary["Company"]="HCL"#Adding of Value 1
print (Dictionary)
Dictionary["Client"]="MunichRe"#Adding of Value 2
print (Dictionary)
del Dictionary["Client"]#deletion
print (Dictionary)
# Out:
# Harish Jawahar
# Jawahar Sankarlingam
# Meenakumari Arultharumperumal
# Hemahlathaa Muthukrishnan
# ['Singapoore', 'India', 'United States of America', 'Canada', 'Malaysia', 'Indonesia']
# India
# {'Name': 'Harish Jawahar', 'Father': 'Jawahar Sankarlingam', 'Mother': 'Meenakumari Arultharumperumal', 'Spouse': 'Hemahlathaa Muthukrishnan', 'Country in which having visa': ['Singapoore', 'India', 'United States of America', 'Canada', 'Malaysia', 'Indonesia'], 'Nationality': 'India'}
# {'Name': 'Harish J', 'Father': 'Jawahar Sankarlingam', 'Mother': 'Meenakumari Arultharumperumal', 'Spouse': 'Hemahlathaa Muthukrishnan', 'Country in which having visa': ['Singapoore', 'India', 'United States of America', 'Canada', 'Malaysia', 'Indonesia'], 'Nationality': 'India'}
# ...
