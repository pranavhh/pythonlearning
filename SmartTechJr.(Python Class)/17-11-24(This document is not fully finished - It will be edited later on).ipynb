# %%
a = ['Python' , "Java"]
b= ['Python' , "Java"]
c=a
print(a is b)#It will come False because , unlike == is depends on the object
#Eventhough they have the same value this will be wrong because it is not the same object
print(c is a)#It will come true because we gave the same object to both the variables
# Out:
# False
# True

# %%
a = ['Python' , "Java"]
b= ['Python' , "Java"]
c=a
print(a is not b)
print(c is not a)
#is not is the opposite of is in python too
# Out:
# True
# False

# %%
a = ["Java" , "Python" , "y"]
print ("python" in a )
print ("Python" in a)
print ("html" in a)
# Out:
# False
# True
# False

# %%
mylist= ['java' , 'html' , 'python' , "SQL" , "C++" , "Android" , "Artificial Intelligence"]
mylist2=[2,4,5,6,7]
mylist3=[True , False]
mylist4=["Java" , 50 , 'Python', True , 60]
print(mylist)
print(len(mylist))
print(mylist2)
print(mylist3)
print(mylist4)
print(mylist4[0])
print(mylist4[1])
print(mylist4[-1])
print(mylist[2:5])
print(mylist[:4])
print(mylist[2:])
print(mylist[:])
mylist[1]= 'website'
print(mylist)
mylist[1:2]="website" , "pandas"
print(mylist)
# Out:
# ['java', 'html', 'python', 'SQL', 'C++', 'Android', 'Artificial Intelligence']
# 7
# [2, 4, 5, 6, 7]
# [True, False]
# ['Java', 50, 'Python', True, 60]
# Java
# 50
# 60
# ['python', 'SQL', 'C++']
# ['java', 'html', 'python', 'SQL']
# ['python', 'SQL', 'C++', 'Android', 'Artificial Intelligence']
# ['java', 'html', 'python', 'SQL', 'C++', 'Android', 'Artificial Intelligence']
# ['java', 'website', 'python', 'SQL', 'C++', 'Android', 'Artificial Intelligence']
# ['java', 'website', 'pandas', 'python', 'SQL', 'C++', 'Android', 'Artificial Intelligence']
