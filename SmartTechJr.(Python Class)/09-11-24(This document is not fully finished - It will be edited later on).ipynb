# %% [markdown]
# **Booleans**
#
# Booleans are just True or False
#
# Let us see how to know if a specific string starts with a/some characters -if you did it right, It should print True if the string starts with a/some characters and if not, it should print False. This specific scenario of booleans is called string
# manipulation

# %%
txt = "I Love Python"
X = txt.startswith ("I")
print (X)
# Out:
# True

# %% [markdown]
# Let us see how to check if some mathematical statments are correct. This is easy you can do it by putting the mathematical statement in a variable or you can do it directly by putting it in a print statment

# %%
A=10>9
B=10==9# '==' is the symbol for is equal to in python
C=10<9

print (A)
print(B)
print (C)



print  (10>9)
print (10==9)
print (10<9)
# Out:
# True
# False
# False
# True
# False
# False

# %% [markdown]
# **If statment**
#
# In Python, the if statement is used to execute a block of code conditionally, based on whether a specified condition evaluates to True or False. It allows you to control the flow of your program by making decisions.

# %%
A=25
B=35

if B>A:
  print ("B is greater than A")
else:
  print ("B is not greater than A")
# Out:
# B is greater than A

# %% [markdown]
# Did you know that you can do mathematical operations with variables that store integers or floats. This is how:

# %%
x=20
y=30

print (x+y)
print (x-y)
print (x*y)
print (x/y)
# Out:
# 50
# -10
# 600
# 0.6666666666666666

# %% [markdown]
# While on the topic of mathematical operations, let me tell you, there is a way to find out the remainder in a division statment, to do this, simply switch the / symbol with a % symbol

# %%
x=5
y=2
print (x%y)
# Out:
# 1

# %%
number=int(input("Enter a number :  "))
if (number % 2) == 0:
  print ("{0} is even".format(number))
else:
  print ("{0} is odd".format(number))
# Out:
# Enter a number :  109
# 109 is odd

# %%
print (" Welcome to the leap year program")
year = int(input("Enter a year : "))

if (year % 4 == 0) and (year % 100 != 0):
  print ("{0} is a leap year".format(year))
elif (year % 400 == 0) and (year % 100 != 0):
  print ("{0} is a leap year".format(year))
else:
  print ("{0} is not a leap year".format(year))
# Out:
#  Welcome to the leap year program
# Enter a year : 2022
# 2022 is not a leap year

# %%
y = "                         Python                              "
X = y.strip()
print ("My favorite program is" ,X, "from childhood")
# Out:
# My favorite program is Python from childhood
